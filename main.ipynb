# %%
# !python main.py
# Out:
# Running cells with 'cpython-3.14.4-macos-aarch64-none (Python 3.14.4)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/Users/prinstonpalmer/.local/share/uv/python/cpython-3.14.4-macos-aarch64-none/bin/python -m pip install ipykernel -U --force-reinstall'
